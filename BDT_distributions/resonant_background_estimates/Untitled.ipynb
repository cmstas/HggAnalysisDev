# %%
import uproot
import awkward as ak
import json
import pandas as pd
import sys
sys.path.append("/home/users/bsathian/HHggTauTau/centralRepo/HggAnalysisDev/Preselection/plots_and_tables/")
import plotter

# %%
df = pd.read_pickle("../../Preselection/output/HHggTauTau_InclusivePresel_20210407_all_resonant_backgrounds.pkl")

# %%
with open("../../Preselection/output/HHggTauTau_InclusivePresel_20210407_all_resonant_backgrounds.json") as f:
    input_json = json.load(f)

# %%
p = plotter.Plotter(df = df, input_options = input_json, branches = "all", plot_options = "plot_options_test.json", debug = 1)
# Out:
# [plotter.py] Loaded dataframe and options

# %%
p.run()
# Out:
# [plotter.py] sample =  Data
# [plotter.py] sample =  DiPhoton
# [plotter.py] sample =  GJets_HT-100To200
# [plotter.py] sample =  GJets_HT-200To400
# [plotter.py] sample =  GJets_HT-400To600
# [plotter.py] sample =  GJets_HT-600ToInf
# [plotter.py] sample =  GJets_HT40To100
# [plotter.py] sample =  HH_ggTauTau
# [plotter.py] sample =  HH_ggWW_dileptonic
# [plotter.py] sample =  HH_ggWW_semileptonic
# [plotter.py] sample =  HH_ggZZ
# [plotter.py] sample =  TTGG
# [plotter.py] sample =  TTGamma
# [plotter.py] sample =  TTbar
# [plotter.py] sample =  VBFH
# [plotter.py] sample =  VH
# [plotter.py] sample =  WGamma
# [plotter.py] sample =  ZGamma
# [plotter.py] sample =  ggH
# [plotter.py] sample =  ttH
# Making plots for branch  gg_mass
# VBFH 6.17972987703979
# ggH 27.344937092624605
# ttH 27.881176066346626
# VH 46.1901519917883
# DiPhoton 7861.215780279599
# GJets 12476.670588731766
# [plotter.py] Rescaling y axis to accommodate legend
# ...

# %%
t = plotter.Plotter(df = df, input_options = input_json, branches = "all", plot_options = "table_options_test.json", debug = 1)
# Out:
# [plotter.py] Loaded dataframe and options

# %%
t.preprocess()
t.fill_hists()
t.make_tables()
# Out:
# [plotter.py] sample =  Data
# [plotter.py] sample =  DiPhoton
# [plotter.py] sample =  GJets_HT-100To200
# [plotter.py] sample =  GJets_HT-200To400
# [plotter.py] sample =  GJets_HT-400To600
# [plotter.py] sample =  GJets_HT-600ToInf
# [plotter.py] sample =  GJets_HT40To100
# [plotter.py] sample =  HH_ggTauTau
# [plotter.py] sample =  HH_ggWW_dileptonic
# [plotter.py] sample =  HH_ggWW_semileptonic
# [plotter.py] sample =  HH_ggZZ
# [plotter.py] sample =  TTGG
# [plotter.py] sample =  TTGamma
# [plotter.py] sample =  TTbar
# [plotter.py] sample =  VBFH
# [plotter.py] sample =  VH
# [plotter.py] sample =  WGamma
# [plotter.py] sample =  ZGamma
# [plotter.py] sample =  ggH
# [plotter.py] sample =  ttH

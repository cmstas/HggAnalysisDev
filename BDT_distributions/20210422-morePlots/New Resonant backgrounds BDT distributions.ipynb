# %%
# %pylab inline
import uproot
import awkward as ak
import sys
sys.path.append("/home/users/bsathian/HHggTauTau/centralRepo/HggAnalysisDev/Preselection/plots_and_tables/")
import plotter
import pandas as pd
import mplhep
plt.style.use(mplhep.style.CMS)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/users/bsathian/miniconda3/envs/analysisenv/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
df_no_selections = pd.read_pickle("/home/users/bsathian/HHggTauTau/centralRepo/HggAnalysisDev/Preselection/output/HHggTauTau_InclusivePresel_20210423_all_resonant_backgrounds.pkl")

# %%
df_no_selections["ele1_phi"].max()
# Out:
# 3.1416015625

# %%
df = df_no_selections.loc[df_no_selections["n_tau"] >= 1].copy()

# %%
df.drop(labels = "genZ_decayMode", axis = 1, inplace = True)

# %%
# Replace unphysical values with NaN

df.loc[df["ele1_pt"] < 0, "ele1_eta"] = np.nan
df.loc[df["ele1_pt"] < 0, "ele1_phi"] = np.nan
df.loc[df["ele1_pt"] < 0, "ele1_tightId"] = np.nan
df.loc[df["ele1_pt"] < 0, "ele1_pt"] = np.nan

df.loc[df["ele2_pt"] < 0, "ele2_eta"] = np.nan
df.loc[df["ele2_pt"] < 0, "ele2_phi"] = np.nan
df.loc[df["ele2_pt"] < 0, "ele2_tightId"] = np.nan
df.loc[df["ele2_pt"] < 0, "ele2_pt"] = np.nan

df.loc[df["muon1_pt"] < 0, "muon1_eta"] = np.nan
df.loc[df["muon1_pt"] < 0, "muon1_phi"] = np.nan
df.loc[df["muon1_pt"] < 0, "muon1_tightId"] = np.nan
df.loc[df["muon1_pt"] < 0, "muon1_pt"] = np.nan

df.loc[df["muon2_pt"] < 0, "muon2_eta"] = np.nan
df.loc[df["muon2_pt"] < 0, "muon2_phi"] = np.nan
df.loc[df["muon2_pt"] < 0, "muon2_tightId"] = np.nan
df.loc[df["muon2_pt"] < 0, "muon2_pt"] = np.nan

df.loc[df["tau2_pt"] < 0, "tau1_eta"] = np.nan
df.loc[df["tau1_pt"] < 0, "tau1_phi"] = np.nan
df.loc[df["tau1_pt"] < 0, "tau1_id_vs_e"] = np.nan
df.loc[df["tau1_pt"] < 0, "tau1_id_vs_m"] = np.nan
df.loc[df["tau1_pt"] < 0, "tau1_id_vs_j"] = np.nan
df.loc[df["tau1_pt"] < 0, "tau1_pt"] = np.nan

df.loc[df["tau2_pt"] < 0, "tau2_eta"] = np.nan
df.loc[df["tau2_pt"] < 0, "tau2_phi"] = np.nan
df.loc[df["tau2_pt"] < 0, "tau2_id_vs_e"] = np.nan
df.loc[df["tau2_pt"] < 0, "tau2_id_vs_m"] = np.nan
df.loc[df["tau2_pt"] < 0, "tau2_id_vs_j"] = np.nan
df.loc[df["tau2_pt"] < 0, "tau2_pt"] = np.nan

df.loc[df["m_tautauSVFitLoose"] < 0, "pt_tautauSVFitLoose"] = np.nan
df.loc[df["m_tautauSVFitLoose"] < 0, "eta_tautauSVFitLoose"] = np.nan
df.loc[df["m_tautauSVFitLoose"] < 0, "phi_tautauSVFitLoose"] = np.nan
df.loc[df["m_tautauSVFitLoose"] < 0, "dR_tautauSVFitLoose"] = np.nan
df.loc[df["m_tautauSVFitLoose"] < 0, "dR_ggtautauSVFitLoose"] = np.nan
df.loc[df["m_tautauSVFitLoose"] < 0, "m_tautauSVFitLoose"] = np.nan


df.loc[df["jet1_pt"] < 0, "jet1_eta"] = np.nan
df.loc[df["jet1_pt"] < 0, "jet1_phi"] = np.nan
df.loc[df["jet1_pt"] < 0, "jet1_id"] = np.nan
df.loc[df["jet1_pt"] < 0, "jet1_pt"] = np.nan

df.loc[df["jet2_pt"] < 0, "jet2_eta"] = np.nan
df.loc[df["jet2_pt"] < 0, "jet2_phi"] = np.nan
df.loc[df["jet2_pt"] < 0, "jet2_id"] = np.nan
df.loc[df["jet2_pt"] < 0, "jet2_pt"] = np.nan

# %%
df.columns
# Out:
# Index(['gg_mass', 'nJet', 'MET_pt', 'MET_phi', 'diphoton_pt_mgg',
#        'diphoton_rapidity', 'diphoton_delta_R', 'lead_pho_ptmgg',
#        'sublead_pho_ptmgg', 'lead_pho_eta', 'sublead_pho_eta',
#        'lead_pho_idmva', 'sublead_pho_idmva', 'lead_pho_phi',
#        'sublead_pho_phi', 'ele1_pt', 'ele1_eta', 'ele1_phi', 'ele2_pt',
#        'ele2_eta', 'ele2_phi', 'ele1_tightId', 'ele2_tightId', 'muon1_pt',
#        'muon1_eta', 'muon1_phi', 'muon2_pt', 'muon2_eta', 'muon2_phi',
#        'muon1_tightId', 'muon2_tightId', 'tau1_pt', 'tau1_eta', 'tau1_phi',
#        'tau2_pt', 'tau2_eta', 'tau2_phi', 'tau1_id_vs_e', 'tau1_id_vs_m',
#        'tau1_id_vs_j', 'tau2_id_vs_e', 'tau2_id_vs_m', 'tau2_id_vs_j', 'n_tau',
#        'n_electrons', 'n_muons', 'jet1_pt', 'jet1_eta', 'jet1_id',
#        'jet1_bTagDeepFlavB', 'jet2_pt', 'jet2_eta', 'jet2_id',
#        'jet2_bTagDeepFlavB', 'pt_tautauSVFitLoose', 'eta_tautauSVFitLoose',
#        'phi_tautauSVFitLoose', 'm_tautauSVFitLoose', 'dR_tautauSVFitLoose',
#        'dR_ggtautauSVFitLoose', 'Category_pairsLoose', 'process_id', 'weight',
#        'year', 'jet1_phi', 'jet2_phi', 'dphi_MET_tau1'],
#       dtype='object')

# %%
df["Category_pairsLoose"].hist()
# Out:
# <AxesSubplot:>

# %%
import json
with open("/home/users/bsathian/HHggTauTau/centralRepo/HggAnalysisDev/Preselection/output/HHggTauTau_InclusivePresel_20210423_all_resonant_backgrounds.json") as f:
    input_options = json.load(f)

# %%
with open("bdt_distributions.json") as f:
    plot_options = json.load(f)

# %%
df["dphi_MET_tau1"] = df["MET_phi"] - df["tau1_phi"]
df.loc[(df["dphi_MET_tau1"] > np.pi) & (df["dphi_MET_tau1"] < 2 * np.pi), "dphi_MET_tau1"] -= 2 * np.pi
df.loc[(df["dphi_MET_tau1"] > -2 * np.pi) & (df["dphi_MET_tau1"] < -np.pi), "dphi_MET_tau1"] += 2 * np.pi

# %%
df.to_pickle("../../Preselection/output/HHggTauTau_InclusivePresel_20210423_all_resonant_backgrounds_with_nan.pkl")

# %%
svfit_plotter = plotter.Plotter(df = df, input_options = input_options, plot_options = plot_options, branches = ["m_tautauSVFitLoose"])
svfit_plotter.run()
# Out:
# Making plots for branch  m_tautauSVFitLoose
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %%
x = plotter.Plotter(df = df, input_options = input_options, plot_options = plot_options, branches = ["jet1_bTagDeepFlavB"])
x.run()
# Out:
# Making plots for branch  jet1_bTagDeepFlavB
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %%
df["dR_tautauSVFitLoose"]
# Out:
# 0         2.017577
# 1         2.712509
# 2              NaN
# 3              NaN
# 4         0.507268
#             ...
# 815833         NaN
# 815834         NaN
# 815835         NaN
# 815836         NaN
# 815837         NaN
# Name: dR_tautauSVFitLoose, Length: 815838, dtype: float32

# %%
svfit_plotter = plotter.Plotter(df = df, input_options = input_options, plot_options = plot_options, branches = ["all"])
svfit_plotter.run()
# Out:
# [plotter.py] mva_score not found in the dataframe. Skipping..                                .
# [plotter.py] mva_without_gen not found in the dataframe. Skipping..                                .
# Making plots for branch  gg_mass
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  diphoton_pt_mgg
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  diphoton_rapidity
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  lead_pho_ptmgg
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  sublead_pho_ptmgg
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  lead_pho_eta
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  sublead_pho_eta
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  lead_pho_phi
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  sublead_pho_phi
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  lead_pho_idmva
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  sublead_pho_idmva
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  n_electrons
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  n_muons
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  n_tau
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  pt_tautauSVFitLoose
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  eta_tautauSVFitLoose
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  phi_tautauSVFitLoose
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  jet2_bTagDeepFlavB
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  jet1_bTagDeepFlavB
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  m_tautauSVFitLoose
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# /home/users/bsathian/HHggTauTau/centralRepo/HggAnalysisDev/Preselection/plots_and_tables/plotter.py:263: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax1 = plt.subplots()
# Making plots for branch  ele1_pt
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  ele1_eta
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  ele1_phi
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  muon1_pt
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  muon1_eta
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  muon1_phi
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  tau1_pt
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  tau1_eta
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  tau1_phi
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  tau2_pt
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  tau2_eta
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  tau2_phi
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  tau1_id_vs_e
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  tau1_id_vs_m
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  tau1_id_vs_j
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  tau2_id_vs_e
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  tau2_id_vs_m
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  tau2_id_vs_j
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  jet1_pt
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  jet1_eta
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  jet1_id
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  jet2_pt
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  jet2_eta
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  jet2_id
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  dR_tautauSVFitLoose
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  dR_ggtautauSVFitLoose
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  diphoton_delta_R
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# Making plots for branch  mva_with_gen
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-ee01c7201482> in <module>
#       1 svfit_plotter = plotter.Plotter(df = df, input_options = input_options, plot_options = plot_options, branches = ["all"])
# ----> 2 svfit_plotter.run()
#
# ~/HHggTauTau/centralRepo/HggAnalysisDev/Preselection/plots_and_tables/plotter.py in run(self)
#     131         self.preprocess()
#     132         self.fill_hists()
# --> 133         self.make_plots()
#     134         return
#     135
#
# ~/HHggTauTau/centralRepo/HggAnalysisDev/Preselection/plots_and_tables/plotter.py in make_plots(self)
#     256         for idx, branch in enumerate(self.branches):
#     257             print("Making plots for branch ", branch)
# --> 258             if "Data" in self.histograms[branch]:
#     259                 fig, (ax1, ax2) = plt.subplots(
#     260                     2, sharex=True, gridspec_kw=dict(height_ratios=[3, 1])
#
# KeyError: 'mva_with_gen'

# %%
df.loc[df["ele1_phi"] > np.pi,"ele1_phi"]

# %%
plot_options["ele1_phi"]

# %%
df["dphi_MET_tau1"].max()
# Out:
# 3.1415837446795862

# %%
plot_options["dphi_MET_tau1"] = {'bin_type': 'linspace',
 'bins': [-6.3, 6.3, 100],
'processes': ['VH', 'ttH', 'ggH', 'VBFH', 'signal'],
  #'processes':['VBFH','signal'],
  'normalize':"unit_area",
 #'stack': 1,
 'signal_scaling': 1000,
 'yaxis': 'log',
 'title': r"$\Delta\phi(MET,Leading $\tau$)",
 'cms_label': 1,
 'output_name': 'dphi_MET_tau1_all.pdf'}

# %%
svfit_plotter = plotter.Plotter(df = df, input_options = input_options, plot_options = plot_options, branches = ["dphi_MET_tau1"])
svfit_plotter.run()
svfit_plotter.make_tables()
# Out:
# Making plots for branch  dphi_MET_tau1
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %%
df.loc[(~np.isnan(df["ele1_tightId"])) & (df["ele1_phi"] > np.pi), "ele1_tightId"]
# Out:
# 76387     1.0
# 425960    1.0
# 614394    1.0
# 615917    1.0
# Name: ele1_tightId, dtype: float64

# %%
df["ele1_eta"].hist()
# Out:
# <AxesSubplot:>

# %%
df.to_pickle("../../Preselection/output/HHggTauTau_InclusivePresel_20210423_all_resonant_backgrounds_with_nan.pkl")

# %%
# %%bash
# cp ../../Preselection/output/HHggTauTau_InclusivePresel_20210423_all_resonant_backgrounds.json ../../Preselection/output/HHggTauTau_InclusivePresel_20210423_all_resonant_backgrounds_with_nan.json

# %%
len(df.loc[df["process_id"] == -1])
# Out:
# 735226

# %%
len(df.loc[df["process_id"] != -1])
# Out:
# 80612

# %% [markdown]
# ### BDT evaluation metrics

# %%
df_bdt = pd.read_pickle("/home/users/bsathian/HHggTauTau/centralRepo/HggAnalysisDev/Preselection/output/HHggTauTau_InclusivePresel_20210423_all_resonant_backgrounds_with_nan_with_bdt_score.pkl")

# %%
with open("bdt_distributions.json") as f:
    plot_options = json.load(f)

# %%
x = plotter.Plotter(df = df_bdt.loc[df_bdt["train_label"] == 2], input_options = input_options, plot_options = "bdt_distributions.json", branches = ["mva_score"])
x.run()
# Out:
# Making plots for branch  mva_score
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %%
for process,hist in x.histograms["mva_score"].items():
    if "signal" not in process:
        print("{} 99th percentile at {}".format(process,hist.quantile(0.99)))
    else:
        print("signal 99th percentile from right (i.e., 1st percentile from left) at {}".format(hist.quantile(0.01)))
# Out:
# VH 99th percentile at 0.9693877551020408
# ttH 99th percentile at 0.8877551020408163
# ggH 99th percentile at 0.6224489795918368
# VBFH 99th percentile at 0.7448979591836735
# signal 99th percentile from right (i.e., 1st percentile from left) at 0.030612244897959183

# %%
plot_options["mva_score"]["processes"] = ["signal","VH"]
x = plotter.Plotter(df = df_bdt.loc[df_bdt["train_label"] == 2], input_options = input_options, plot_options = plot_options, branches = ["mva_score"], save_filenames = "mva_score_signal_vs_VH.pdf")
x.run()
# Out:
# Making plots for branch  mva_score
# 'texgyreheros-bold.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-italic.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %%
x.histograms["mva_score"]["VH"].
# Out:
# <AxesSubplot:>

# %%
x.histograms["mva_score"]["VH"].restrict(0,0.6).integral/x.histograms["mva_score"]["VH"].integral
# Out:
# 0.72561163358291

# %%
x.histograms["mva_score"]["signal"].restrict(0,0.6).integral/x.histograms["mva_score"]["signal"].integral
# Out:
# 0.8334947555760341

# %%
x.histograms["mva_score"]["ggH"].restrict(0,0.6).integral/x.histograms["mva_score"]["ggH"].integral
# Out:
# 0.9855412153685906

# %%
x.histograms["mva_score"]["ttH"].restrict(0,0.6).integral/x.histograms["mva_score"]["ttH"].integral
# Out:
# 0.9284397196895032

# %%
x.histograms["mva_score"]["VBFH"].restrict(0,0.6).integral/x.histograms["mva_score"]["VBFH"].integral
# Out:
# 0.9564430915533872

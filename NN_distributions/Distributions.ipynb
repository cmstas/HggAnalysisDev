# %%
# %pylab inline
import uproot
import awkward as ak
import sys
sys.path.append("/home/users/bsathian/HHggTauTau/centralRepo/HggAnalysisDev/Preselection/plots_and_tables/")
import plotter
import pandas as pd
import mplhep
plt.style.use(mplhep.style.CMS)
from yahist import Hist1D, Hist2D
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
tau_flat_df = pd.read_pickle("/nfs-7/userdata/bsathian/singleH_extended_mass_take2_with_DNN_mass_with_cov.pkl")
tau_flat_df_before_prep = pd.read_pickle("../Preselection/output/singleH_nanoAOD_extended_mass_take2.pkl")

# %%
tau_pt_hist = Hist1D(tau_flat_df_before_prep.loc[tau_flat_df_before_prep["Category_pairsLoose"] > -1, "decay_1_pt"], bins=arange(0,1000,10))
plt.yscale("log")
tau_pt_hist.plot()
# Out:
# <AxesSubplot:>

# %%
tau_pt_normalized_hist = Hist1D(tau_flat_df.loc[tau_flat_df["Category_pairsLoose"] > -1, "decay_1_pt"], bins=arange(0,10,0.02))
plt.yscale("log")
tau_pt_normalized_hist.plot()
# Out:
# <AxesSubplot:>

# %%
tau_pt_hist = Hist1D(log(tau_flat_df_before_prep.loc[tau_flat_df_before_prep["Category_pairsLoose"] > -1, "decay_1_pt"])/(tau_flat_df_before_prep.loc[tau_flat_df_before_prep["Category_pairsLoose"] > -1, "m_tautau_vis"]), bins=arange(0,2,0.01))
plt.yscale("log")
tau_pt_hist.plot()
# Out:
# <AxesSubplot:>

# %%
x = log(tau_flat_df_before_prep.loc[tau_flat_df_before_prep["Category_pairsLoose"] > -1, "decay_1_pt"])/(tau_flat_df_before_prep.loc[tau_flat_df_before_prep["Category_pairsLoose"] > -1, "m_tautau_vis"])
Hist1D((x - x.mean())/x.std(), bins=linspace(-1, 1, 100)).plot()
# Out:
# <AxesSubplot:>

# %%
z = (tau_flat_df_before_prep.loc[tau_flat_df_before_prep["Category_pairsLoose"] > -1, "decay_1_pt"])/(tau_flat_df_before_prep.loc[tau_flat_df_before_prep["Category_pairsLoose"] > -1, "m_tautau_vis"])
Hist1D((z - z.mean())/z.std(), bins=linspace(-1, 1, 100)).plot()
# Out:
# <AxesSubplot:>

# %%
x2 = log(tau_flat_df_before_prep.loc[tau_flat_df_before_prep["Category_pairsLoose"] > -1, "decay_2_pt"])/(tau_flat_df_before_prep.loc[tau_flat_df_before_prep["Category_pairsLoose"] > -1, "m_tautau_vis"])
Hist1D((x2 - x2.mean())/x2.std(), bins=linspace(-1, 1, 100)).plot()
# Out:
# <AxesSubplot:>

# %%
z2 = (tau_flat_df_before_prep.loc[tau_flat_df_before_prep["Category_pairsLoose"] > -1, "decay_2_pt"])/(tau_flat_df_before_prep.loc[tau_flat_df_before_prep["Category_pairsLoose"] > -1, "m_tautau_vis"])
Hist1D((z2 - z2.mean())/z2.std(), bins=linspace(-1, 1, 100)).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Jet multiplicity stuff

# %%
tau_flat_df.loc[tau_flat_df["Category_pairsLoose"] > -1, "nJet"].hist()
# Out:
# <AxesSubplot:>

# %%
tau_flat_df.loc[(tau_flat_df["Category_pairsLoose"] > -1) & (tau_flat_df["nJet"] >= 2), "jet1_pt"]
# Out:
# <AxesSubplot:>

# %%
(tau_flat_df.loc[(tau_flat_df["Category_pairsLoose"] > -1) & (tau_flat_df["jet1_pt"] >= 0), "jet1_pt"]/tau_flat_df.loc[(tau_flat_df["Category_pairsLoose"] > -1) & (tau_flat_df["jet1_pt"] >= 0), "m_tautau_vis"]).mean()
# Out:
# 1.2108133023900522
